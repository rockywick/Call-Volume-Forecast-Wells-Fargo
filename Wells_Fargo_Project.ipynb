# %% [markdown]
# # Credit Card Call Volume Forecast
#
# Link to the Problem Statement : https://drive.google.com/file/d/1pRvWauSQWGz3TWNpsfIJB06W3sasGg7X/view?usp=sharing

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Let us start by importing all necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error


from statsmodels.tsa.seasonal import seasonal_decompose
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.losses import MAPE
from keras.losses import mse
from keras.optimizers import Adam

# %% [markdown]
# Let us reading the given CSV file

# %%
df = pd.read_csv("data.csv")

df
# Out:
#            Date  No_of_calls_from_commercial_card  \
# 0      1/1/2017                             264.0
# 1      1/2/2017                             528.0
# 2      1/3/2017                            2505.0
# 3      1/4/2017                            2145.0
# 4      1/5/2017                            2164.0
# ...         ...                               ...
# 1668  7/27/2021                               NaN
# 1669  7/28/2021                               NaN
# 1670  7/29/2021                               NaN
# 1671  7/30/2021                               NaN
# 1672  7/31/2021                               NaN
#
#       No_of_calls_from_retail_card  No_of_calls_from_student_card
# 0                            403.0                          860.0
# 1                            792.0                         1681.0
# 2                           3774.0                         7639.0
# 3                           3236.0                         6513.0
# 4                           3265.0                         6604.0
# ...                            ...                            ...
# 1668                           NaN                            NaN
# 1669                           NaN                            NaN
# 1670                           NaN                            NaN
# 1671                           NaN                            NaN
# 1672                           NaN                            NaN
#
# [1673 rows x 4 columns]

# %% [markdown]
# From the problem statement, we know that the values given for the first year are accurate and the rest of the given values are scrambled. So we will first look at the accurate values

# %%
commercial_card_accurate = df['No_of_calls_from_commercial_card'][:365]
retail_card_accurate = df['No_of_calls_from_retail_card'][:365]
student_card_accurate = df['No_of_calls_from_student_card'][:365]

date = df['Date']

# %% [markdown]
# Let us now observe the trend of these values over a small range, let us say the first 21 values (3 weeks)

# %%
x_axis = date[:21]
y_axis1 = commercial_card_accurate[:21]
y_axis2 = retail_card_accurate[:21]
y_axis3 = student_card_accurate[:21]

plt.plot(x_axis, y_axis1, color='blue', label='Commercial Card')
plt.plot(x_axis, y_axis2, color='orange', label='Retail Card')
plt.plot(x_axis, y_axis3, color='green', label='Student Card')

plt.xlabel('Number of calls')
plt.ylabel('Date')
plt.legend()

plt.show()

# %% [markdown]
# The first thing that we can observe from the graph is that the number of calls for student cards > number of calls for retail cards > number of cards for commercial calls
#
# To verify this, let us check if this trend is valid throughout the dataset

# %%
#to verify that retail card>retail card>student card

i=0
for i in range (365):
    if (student_card_accurate[i]<retail_card_accurate[i] or student_card_accurate[i]<commercial_card_accurate[i] or retail_card_accurate[i]<commercial_card_accurate[i]):
        print(i)

# %% [markdown]
# Since no output was generated, this means that the trend always holds true. So we can sort the remaining days according to this trend.
#
# Let us store the accurate values in a list, and the unsorted values after sorting

# %%
#sorting the values and storing them in lists

commerical_card_complete=[]
retail_card_complete=[]
student_card_complete=[]

for i in range (0,365):
    commerical_card_complete.append(commercial_card_accurate[i])
    retail_card_complete.append(retail_card_accurate[i])
    student_card_complete.append(student_card_accurate[i])

for i in range (365,1581):
    a=df.iloc[i]['No_of_calls_from_commercial_card']
    b=df.iloc[i]['No_of_calls_from_retail_card']
    c=df.iloc[i]['No_of_calls_from_student_card']

    calls = [a,b,c]
    calls.sort()

    commerical_card_complete.append(calls[0])
    retail_card_complete.append(calls[1])
    student_card_complete.append(calls[2])

# %% [markdown]
# Let us now create a new dataframe of these accurate values
#
# As the problem statement asked us to create csv files for the entire dataset as well as just for the commercial card call vilume data, we shall create 2 new dataframes

# %%
#to create a new dataframe
corrected_data=[]
corrected_data_commercial=[]

for i in range (0,1581):
    date = df["Date"][i]
    com = commerical_card_complete[i]
    ret = retail_card_complete[i]
    stu = student_card_complete[i]
    corrected_data_row = [date,com,ret,stu]
    corrected_data_commercial_row = [date,com]
    corrected_data.append(corrected_data_row)
    corrected_data_commercial.append(corrected_data_commercial_row)

# %% [markdown]
# Lets us now store the data in a new csv file

# %%
corrected_df=pd.DataFrame(corrected_data,columns=['Date','No_of_calls_from_commercial_card','No_of_calls_from_retail_card','No_of_calls_from_student_card'])
corrected_df = corrected_df.set_index('Date')
corrected_df.to_csv('Corrected_Data.csv')

# %%
corrected_commercial_df = pd.DataFrame(corrected_data_commercial,columns=['Date','No_of_calls_from_commercial_card'])
corrected_commercial_df = corrected_commercial_df.set_index('Date')
corrected_commercial_df.to_csv('Corrected_Commercial_Data.csv')

# %% [markdown]
# Let us plot all the values and try to see if we can interpret anything

# %%
# plotting commercial card call volume

x_values = [element[0] for element in corrected_data]
y_values = [element[1] for element in corrected_data]

plt.plot(x_values, y_values)
plt.ylabel('Commercial Card Volume')
plt.show()

# %% [markdown]
# Unfortunately, the data seems to reduce towards the end. This could negatively affect our training as we would train it on a relatively higher range of values, but expect the output to be in a much smaller range.
#
# So we will take relatively larger training sets to have more accurate predictions

# %% [markdown]
# Let us now try to see if any reptitive patterns can be broken down from the data. Let us analyse the first 120 values

# %%
#plotting for the first 120 values to see any repititive trend

newdf = pd.read_csv('Corrected_Commercial_Data.csv', index_col='Date', parse_dates=True)

results = seasonal_decompose(newdf['No_of_calls_from_commercial_card'][:120], model = 'additive')
results.plot()

# %% [markdown]
# Clearly the trend is extremely irregular so we clearly do not have any repititive behaviour in our data

# %% [markdown]
# ## Predicting values from the data

# %% [markdown]
# Let us start by reading the CSV file where we stored all the accurate data

# %%
maindf = pd.read_csv('Corrected_Data.csv', index_col='Date', parse_dates=True)

newdf = maindf
newdf
# Out:
#             No_of_calls_from_commercial_card  No_of_calls_from_retail_card  \
# Date
# 2017-01-01                             264.0                         403.0
# 2017-01-02                             528.0                         792.0
# 2017-01-03                            2505.0                        3774.0
# 2017-01-04                            2145.0                        3236.0
# 2017-01-05                            2164.0                        3265.0
# ...                                      ...                           ...
# 2021-04-26                            1392.0                        2094.0
# 2021-04-27                            1336.0                        2014.0
# 2021-04-28                            1220.0                        1831.0
# 2021-04-29                            1094.0                        1661.0
# 2021-04-30                            1119.0                        1689.0
#
#             No_of_calls_from_student_card
# Date
# 2017-01-01                          860.0
# 2017-01-02                         1681.0
# 2017-01-03                         7639.0
# 2017-01-04                         6513.0
# 2017-01-05                         6604.0
# ...                                   ...
# 2021-04-26                         4278.0
# 2021-04-27                         4038.0
# 2021-04-28                         3737.0
# 2021-04-29                         3391.0
# 2021-04-30                         3440.0
#
# [1581 rows x 3 columns]

# %% [markdown]
# From the graph of trend of number of calls vs the date, one more thing that we can notice is that the number of calls drop drastically on the weekends, as compared to the weekdays. So let us number the days of the week according to the total number of calls that come in throughout the duration

# %%
days = [(i%7) for i in range(1581)]

newdf['Commercial_Days'] = days
newdf['Retail_Days'] = days
newdf['Student_Days'] = days

list_days_com = [0,0,0,0,0,0,0]
list_days_ret = [0,0,0,0,0,0,0]
list_days_stu = [0,0,0,0,0,0,0]

for i in newdf.index:
    list_days_com[newdf['Commercial_Days'][i]]+=newdf['No_of_calls_from_commercial_card'][i]
    list_days_ret[newdf['Retail_Days'][i]]+=newdf['No_of_calls_from_retail_card'][i]
    list_days_stu[newdf['Student_Days'][i]]+=newdf['No_of_calls_from_student_card'][i]

count=0
for i in newdf.index:
    newdf['Commercial_Days'][i]=list_days_com[count%7]
    newdf['Retail_Days'][i]=list_days_ret[count%7]
    newdf['Student_Days'][i]=list_days_stu[count%7]
    count+=1
# Out:
# /var/folders/13/twz8kwfs1qv_4w_c6dzc_57m0000gn/T/ipykernel_6320/2497239699.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Commercial_Days'][i]=list_days_com[count%7]
# /var/folders/13/twz8kwfs1qv_4w_c6dzc_57m0000gn/T/ipykernel_6320/2497239699.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Retail_Days'][i]=list_days_ret[count%7]
# /var/folders/13/twz8kwfs1qv_4w_c6dzc_57m0000gn/T/ipykernel_6320/2497239699.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Student_Days'][i]=list_days_stu[count%7]

# %%
newdf[:8]
# Out:
#             No_of_calls_from_commercial_card  No_of_calls_from_retail_card  \
# Date
# 2017-01-01                             264.0                         403.0
# 2017-01-02                             528.0                         792.0
# 2017-01-03                            2505.0                        3774.0
# 2017-01-04                            2145.0                        3236.0
# 2017-01-05                            2164.0                        3265.0
# 2017-01-06                            1787.0                        2697.0
# 2017-01-07                             464.0                         715.0
# 2017-01-08                             505.0                         758.0
#
#             No_of_calls_from_student_card  Commercial_Days  Retail_Days  \
# Date
# 2017-01-01                          860.0            88531       135072
# 2017-01-02                         1681.0           425170       639968
# 2017-01-03                         7639.0           424392       638766
# 2017-01-04                         6513.0           405112       609860
# 2017-01-05                         6604.0           391126       589052
# 2017-01-06                         5482.0           355613       535701
# 2017-01-07                         1449.0            96966       147517
# 2017-01-08                         1574.0            88531       135072
#
#             Student_Days
# Date
# 2017-01-01        281640
# 2017-01-02       1291397
# 2017-01-03       1287875
# 2017-01-04       1231015
# 2017-01-05       1189596
# 2017-01-06       1082564
# 2017-01-07        306137
# 2017-01-08        281640

# %% [markdown]
# We have now marked every day of the week according to the total number of calls on that specific weekday, throughout the year

# %% [markdown]
# Let us now create the training set and the test set
#
# Note that due to the reducing range of values as noticed from the graph above, the test set is small compared to the training set

# %%
train = newdf[:1500]
test = newdf[1500:]
full = newdf

# %% [markdown]
# Let us now scale down the values to help the model train data easily

# %%
scaler = MinMaxScaler()

scaler.fit(train)
scaled_train = scaler.transform(train)

scaler.fit(test)
scaled_test = scaler.transform(test)

scaler.fit(full)
scaled_full = scaler.transform(full)

# %%
type(scaled_train)
# Out:
# numpy.ndarray

# %% [markdown]
# We now need to select the number of inputs (window size). After experimenting with different values, 7 seems like an optimal window size as it is large enough to contain all the days of the week and can hence train the sudden drop on the weekends. A larger window size might not result in such accurate predictions

# %% [markdown]
# The time series generator hels us create out training examples

# %%
n_input = 7
n_features = 6

generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)
X,y  = generator[0]
X.shape
# Out:
# (1, 7, 6)

# %%
type(y)
# Out:
# numpy.ndarray

# %% [markdown]
# Let us now build the model. Having experimented with various layers and number of neurons, this model seems to be a good fit for the data. I have trained it using the Adam Optimiser and the Mean_Squared_Error loss function

# %%
model = Sequential()
model.add(LSTM(64, activation="relu", input_shape = (n_input,n_features), return_sequences = True))
model.add(LSTM(32, activation="relu", return_sequences = False))
model.add(Dropout(0.2))
model.add(Dense(6))
model.compile(optimizer="Adam", loss="mse")

# %% [markdown]
# Let us now train the model for 50 epochs as the values seem to converge after roughly 30-40 epochs

# %%
model.fit(generator, epochs = 50)
# Out:
# Epoch 1/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0424
# Epoch 2/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0145
# Epoch 3/50
# 1493/1493 [==============================] - 4s 3ms/step - loss: 0.0110
# Epoch 4/50
# 1493/1493 [==============================] - 4s 3ms/step - loss: 0.0098
# Epoch 5/50
# 1493/1493 [==============================] - 4s 3ms/step - loss: 0.0092
# Epoch 6/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0083
# Epoch 7/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0084
# Epoch 8/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0082
# Epoch 9/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0076
# Epoch 10/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0078
# Epoch 11/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0077
# Epoch 12/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0071
# Epoch 13/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0072
# Epoch 14/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0073
# Epoch 15/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0070
# Epoch 16/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0072
# Epoch 17/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0072
# Epoch 18/50
# 1493/1493 [==============================] - 4s 3ms/step - loss: 0.0066
# Epoch 19/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0068
# Epoch 20/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0070
# Epoch 21/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0069
# Epoch 22/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0067
# Epoch 23/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0065
# Epoch 24/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0067
# Epoch 25/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0066
# Epoch 26/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0064
# Epoch 27/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0066
# Epoch 28/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0063
# Epoch 29/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0064
# Epoch 30/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0062
# Epoch 31/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0059
# Epoch 32/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0064
# Epoch 33/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0060
# Epoch 34/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0063
# Epoch 35/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0064
# Epoch 36/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0064
# Epoch 37/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0062
# Epoch 38/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0062
# Epoch 39/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0063
# Epoch 40/50
# 1493/1493 [==============================] - 4s 3ms/step - loss: 0.0060
# Epoch 41/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0058
# Epoch 42/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0060
# Epoch 43/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0059
# Epoch 44/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0063
# Epoch 45/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0058
# Epoch 46/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0060
# Epoch 47/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0059
# Epoch 48/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0060
# Epoch 49/50
# 1493/1493 [==============================] - 4s 2ms/step - loss: 0.0057
# Epoch 50/50
# 1493/1493 [==============================] - 3s 2ms/step - loss: 0.0058

# %% [markdown]
# To see how well the model has been trained, let us plot the loss per epoch

# %%
loss_per_epoch = model.history.history["loss"]
x = [(i+1) for i in range (50)]
plt.plot(x,loss_per_epoch)

# %% [markdown]
# The values seem to converge after some time, so 50 epochs is enough

# %% [markdown]
# Let us now make predicitions for the next set of values to compare it with the training set

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(scaled_test)):

    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]

    # append the prediction into the array
    test_predictions.append(current_pred)

    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[scaled_test[i]]],axis=1)
    # current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step

# %% [markdown]
# Since the values have been scaled down, wemust first get back our original values before we can calculate the score

# %%
true_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform(scaled_test)

score = mean_absolute_percentage_error(y_test, true_predictions)
score
# Out:
# 0.31246958794443386

# %% [markdown]
# Although the MAPE score is relatively high, it can be explained by the drop in values as we get to the later stages

# %% [markdown]
# Let us now predict the values to fill the initial CSV file (until 7/31/2021)

# %%
#short term forecast
predictions = []

first_eval_batch = scaled_full[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(92):

    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]

    # append the prediction into the array
    predictions.append(current_pred)

    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step

# %% [markdown]
# We can now see the predicted values

# %%
true_predictions = scaler.inverse_transform(predictions)
true_predictions[91][:3]
# Out:
# array([ 534.25936696,  812.31525493, 1681.38285291])

# %% [markdown]
# Let us append these values to the maindf dataframe

# %%
maindf
# Out:
#             No_of_calls_from_commercial_card  No_of_calls_from_retail_card  \
# Date
# 2017-01-01                             264.0                         403.0
# 2017-01-02                             528.0                         792.0
# 2017-01-03                            2505.0                        3774.0
# 2017-01-04                            2145.0                        3236.0
# 2017-01-05                            2164.0                        3265.0
# ...                                      ...                           ...
# 2021-04-26                            1392.0                        2094.0
# 2021-04-27                            1336.0                        2014.0
# 2021-04-28                            1220.0                        1831.0
# 2021-04-29                            1094.0                        1661.0
# 2021-04-30                            1119.0                        1689.0
#
#             No_of_calls_from_student_card  Commercial_Days  Retail_Days  \
# Date
# 2017-01-01                          860.0            88531       135072
# 2017-01-02                         1681.0           425170       639968
# 2017-01-03                         7639.0           424392       638766
# 2017-01-04                         6513.0           405112       609860
# 2017-01-05                         6604.0           391126       589052
# ...                                   ...              ...          ...
# 2021-04-26                         4278.0           425170       639968
# 2021-04-27                         4038.0           424392       638766
# 2021-04-28                         3737.0           405112       609860
# 2021-04-29                         3391.0           391126       589052
# 2021-04-30                         3440.0           355613       535701
#
#             Student_Days
# Date
# 2017-01-01        281640
# 2017-01-02       1291397
# 2017-01-03       1287875
# 2017-01-04       1231015
# 2017-01-05       1189596
# ...                  ...
# 2021-04-26       1291397
# 2021-04-27       1287875
# 2021-04-28       1231015
# 2021-04-29       1189596
# 2021-04-30       1082564
#
# [1581 rows x 6 columns]

# %%
last_date = maindf.index[-1]

for i in range(92):
    new_date = last_date + pd.DateOffset(days=i+1)
    new_row = [round(true_predictions[i][0]), round(true_predictions[i][1]), round(true_predictions[i][2])]

    # new_row_series = pd.Series(new_row, index = maindf.columns)
    maindf.loc[new_date] = new_row

maindf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [55], line 8
#       5     new_row = [round(true_predictions[i][0]), round(true_predictions[i][1]), round(true_predictions[i][2])]
#       7     # new_row_series = pd.Series(new_row, index = maindf.columns)
# ----> 8     maindf.loc[new_date] = new_row
#      10 maindf
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexing.py:819, in _LocationIndexer.__setitem__(self, key, value)
#     816 self._has_valid_setitem_indexer(key)
#     818 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 819 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexing.py:1786, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1783     indexer, missing = convert_missing_indexer(indexer)
#    1785     if missing:
# -> 1786         self._setitem_with_indexer_missing(indexer, value)
#    1787         return
#    1789 if name == "loc":
#    1790     # must come after setting of missing
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/indexing.py:2156, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2153     if is_list_like_indexer(value):
#    2154         # must have conforming columns
#    2155         if len(value) != len(self.obj.columns):
# -> 2156             raise ValueError("cannot set a row with mismatched columns")
#    2158     value = Series(value, index=self.obj.columns, name=indexer)
#    2160 if not len(self.obj):
#    2161     # We will ignore the existing dtypes instead of using
#    2162     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns

# %% [markdown]
# Finally, we will store it in a CSV file to conclude the project

# %%
maindf.to_csv('Predicted_Values.csv')
